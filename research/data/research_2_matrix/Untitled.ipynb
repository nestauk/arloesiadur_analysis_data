# %%
import pandas as pd

# %%
data = pd.read_csv('research_heatmap_data.csv')

# %%
data.head()
# Out:
#                                   topic  variable     Wales  Isle of Anglesey  \
# 0                                ageing  count_lq  0.945001          0.000000
# 1  agriculture_plant_biology_entomology  count_lq  0.838203          4.723666
# 2            applications_devices_users  count_lq  1.130551          0.000000
# 3                           archaeology  count_lq  1.254180          0.000000
# 4                  architecture_spatial  count_lq  0.948800          0.000000
#
#     Gwynedd  Conwy  Denbighshire  Flintshire   Wrexham     Powys  \
# 0  1.915294    0.0      0.000000    0.000000  0.000000  0.000000
# 1  1.269602    0.0      0.755787    0.000000  1.988912  3.334353
# 2  0.573036    0.0      0.579913    1.380745  0.763043  1.705626
# 3  1.101007    0.0      5.571098    0.000000  7.330392  0.000000
# 4  2.913405    0.0      0.000000    0.000000  0.000000  0.000000
#
#              ...              Vale of Glamorgan  Rhondda Cynon Taf  \
# ...

# %%
data_long = pd.melt(data,id_vars=['topic','variable','discipline'],var_name='location')

# %%
data_long
# Out:
#                                      topic       variable  \
# 0                                   ageing       count_lq
# 1     agriculture_plant_biology_entomology       count_lq
# 2               applications_devices_users       count_lq
# 3                              archaeology       count_lq
# 4                     architecture_spatial       count_lq
# 5                                astronomy       count_lq
# 6                             astrophysics       count_lq
# 7                          bio_informatics       count_lq
# 8                       biopharmaceuticals       count_lq
# 9                            bones_muscles       count_lq
# 10             carbon_greenhouse_pollution       count_lq
# 11                            cells_cancer       count_lq
# 12                 cellular_biology_cancer       count_lq
# 13                  chemistry_biochemistry       count_lq
# 14               classic_religious_history       count_lq
# ...

# %%
data_long.to_csv('research_heatmap_data_long.csv',index=False)

# %%
for x in data_long.columns:
    print('* **{x}:**'.format(x=x))
# Out:
# * **topic:**
# * **variable:**
# * **discipline:**
# * **location:**
# * **value:**
